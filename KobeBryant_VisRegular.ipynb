# %% [markdown]
# # Regular Vis of Kobe·Bryant

# %% [markdown]
# ## Data load

# %%
import os
import re
import json
import time
import requests
import pandas as pd
import numpy as np
from datetime import *
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType, ChartType
from bs4 import BeautifulSoup
from selenium import webdriver   # 导入浏览器驱动模块
import warnings
warnings.filterwarnings("ignore")  # 忽略版本问题

# %% [markdown]
# ## Regular

# %%
age_m = pd.read_excel('Regular_Age.xlsx', sheet_name='data_age', index_col=0)  # 各年龄段场均数据
win_lose_age = pd.read_excel('Regular_Age.xlsx', sheet_name='win_lose_age', index_col=0)  # 各年龄段胜败场数
home_away_age = pd.read_excel('Regular_Age.xlsx', sheet_name='home_away_age', index_col=0)  # 各年龄段主客场胜败场数
home_away = pd.read_excel('Regular_Age.xlsx', sheet_name='home_away', index_col=0)  # 主客场胜败总数
sp_age = pd.read_excel('Regular_Age.xlsx', sheet_name='dff_point', index_col=0)  # 各年龄段最大输赢分差及正负值
s_age = pd.read_excel('Regular_Age.xlsx', sheet_name='age_sum', index_col=0)  # 各年龄段总数据

# %%
team_m = pd.read_excel('Regular_Team.xlsx', sheet_name='data_team', index_col=0)  # 对阵各队场均数据
win_lose_team = pd.read_excel('Regular_Team.xlsx', sheet_name='win_lose_team', index_col=0)  # 对阵各队胜败场数
home_away_team = pd.read_excel('Regular_Team.xlsx', sheet_name='home_away_team', index_col=0)  # 对阵各队主客场胜败场数
home_away = pd.read_excel('Regular_Team.xlsx', sheet_name='home_away', index_col=0)  # 主客场胜败总数
sp_team = pd.read_excel('Regular_Team.xlsx', sheet_name='dff_point', index_col=0)  # 对阵各队最大输赢分差及正负值
s_team = pd.read_excel('Regular_Team.xlsx', sheet_name='team_sum', index_col=0)  # 对阵各队总数据

# %% [markdown]
# # Pyecharts

# %%
#加载 Jupyter lab中设置 pyecharts 全局显示参数
from pyecharts.globals import CurrentConfig, NotebookType, SymbolType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB     
import pyecharts.options as opts                                     #并加载pyecharts选项
from pyecharts.charts import *
from pyecharts.components import *
from pyecharts.faker import Faker
figsize=opts.InitOpts(width='600px',height='400px', bg_color='rgb(5, 46, 112, 0.5)') #设置图形大小和背景色 rgb(225, 225, 225, 0.5)

Bar().load_javascript();           #绘图前需加载一次JavaScript函数！！
Line().load_javascript();
Map().load_javascript();
Page().load_javascript();
Pie().load_javascript();
WordCloud().load_javascript();
Table().load_javascript();
HeatMap().load_javascript();
Radar().load_javascript();
Timeline().load_javascript()

# %% [markdown]
# ## Testing

# %%
#仪表盘
from pyecharts.charts import Gauge
Gauge().load_javascript()
Gauge().add("",[("完成率\n\n\n",99)]).render_notebook()

# %% [markdown]
# ## Radar

# %% [markdown]
# ### radar1

# %%
v1 = [team_m.loc['ATL'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v2 = [team_m.loc['BOS'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v3 = [team_m.loc['BRK'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v4 = [team_m.loc['CHA'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v5 = [team_m.loc['CHH'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v6 = [team_m.loc['CHI'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v7 = [team_m.loc['CHO'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v8 = [team_m.loc['CLE'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v9 = [team_m.loc['DAL'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v10 = [team_m.loc['DEN'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v11 = [team_m.loc['DET'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v12 = [team_m.loc['GSW'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v13 = [team_m.loc['HOU'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v14 = [team_m.loc['IND'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v15 = [team_m.loc['LAC'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v16 = [team_m.loc['MEM'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v17 = [team_m.loc['MIA'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v18 = [team_m.loc['MIL'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v19 = [team_m.loc['MIN'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v20 = [team_m.loc['NJN'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v21 = [team_m.loc['NOH'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v22 = [team_m.loc['NOK'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v23 = [team_m.loc['NOP'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v24 = [team_m.loc['NYK'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v25 = [team_m.loc['OKC'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v26 = [team_m.loc['ORL'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v27 = [team_m.loc['PHI'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v28 = [team_m.loc['PHO'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v29 = [team_m.loc['POR'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v30 = [team_m.loc['SAC'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v31 = [team_m.loc['SAS'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v32 = [team_m.loc['SEA'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v33 = [team_m.loc['TOR'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v34 = [team_m.loc['UTA'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v35 = [team_m.loc['VAN'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; v36 = [team_m.loc['WAS'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
v37 = [team_m.loc['WSB'][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 

radar_team1 = Radar(figsize)
radar_team1.add_schema(
        schema=[
            opts.RadarIndicatorItem(name="Games", max_=70, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Minutes", max_=40, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Total Rebounds", max_=6.5, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Assists", max_=6, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Steals", max_=2, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Blocks", max_=1, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Turnovers", max_=4, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Personal Fouls", max_=3.5, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Points", max_=34, color='#FFFF99'),
        ],
        shape='circle',
        
)

radar_team1.add('ATL', v1, linestyle_opts=opts.LineStyleOpts(color="#cc082f"),); radar_team1.add('BOS', v2, linestyle_opts=opts.LineStyleOpts(color="#007a30"),); 
radar_team1.add('BRK', v3, linestyle_opts=opts.LineStyleOpts(color="#2d2926"),); radar_team1.add('CHA', v4, linestyle_opts=opts.LineStyleOpts(color="#f63f3a"),); 
radar_team1.add('CHH', v5, linestyle_opts=opts.LineStyleOpts(color="#017589"),); radar_team1.add('CHI', v6, linestyle_opts=opts.LineStyleOpts(color="#bc022b"),); 
radar_team1.add('CHO', v7, linestyle_opts=opts.LineStyleOpts(color="#1e1446"),); radar_team1.add('CLE', v8, linestyle_opts=opts.LineStyleOpts(color="#57263e"),); 
radar_team1.add('DAL', v9, linestyle_opts=opts.LineStyleOpts(color="#0155ba"),); radar_team1.add('DEN', v10, linestyle_opts=opts.LineStyleOpts(color="#498ecb"),); 
radar_team1.add('DET', v11, linestyle_opts=opts.LineStyleOpts(color="#ee154b"),); radar_team1.add('GSW', v12, linestyle_opts=opts.LineStyleOpts(color="#0168b3"),); 
radar_team1.add('HOU', v13, linestyle_opts=opts.LineStyleOpts(color="#d00e42"),); radar_team1.add('IND', v14, linestyle_opts=opts.LineStyleOpts(color="#00255d"),); 
radar_team1.add('LAC', v15, linestyle_opts=opts.LineStyleOpts(color="#f1a8bb"),); radar_team1.add('MEM', v16, linestyle_opts=opts.LineStyleOpts(color="#6189b9"),); 
radar_team1.add('MIA', v17, linestyle_opts=opts.LineStyleOpts(color="#97002e"),); radar_team1.add('MIL', v18, linestyle_opts=opts.LineStyleOpts(color="#e0d4b1"),); 
radar_team1.add('MIN', v19, linestyle_opts=opts.LineStyleOpts(color="#00a950"),); radar_team1.add('NJN', v20, linestyle_opts=opts.LineStyleOpts(color="#09285e"),);
radar_team1.add('NOH', v21, linestyle_opts=opts.LineStyleOpts(color="#0f5a82"),); radar_team1.add('NOK', v22, linestyle_opts=opts.LineStyleOpts(color="#0f5a82"),); 
radar_team1.add('NOP', v23, linestyle_opts=opts.LineStyleOpts(color="#071f3f"),); radar_team1.add('NYK', v24, linestyle_opts=opts.LineStyleOpts(color="#f68327"),); 
radar_team1.add('OKC', v25, linestyle_opts=opts.LineStyleOpts(color="#f15032"),); radar_team1.add('ORL', v26, linestyle_opts=opts.LineStyleOpts(color="#0071bb"),); 
radar_team1.add('PHI', v27, linestyle_opts=opts.LineStyleOpts(color="#033ea6"),); radar_team1.add('PHO', v28, linestyle_opts=opts.LineStyleOpts(color="#f9a11f"),); 
radar_team1.add('POR', v29, linestyle_opts=opts.LineStyleOpts(color="#e93940"),); radar_team1.add('SAC', v30, linestyle_opts=opts.LineStyleOpts(color="#6a47aa"),); 
radar_team1.add('SAS', v31, linestyle_opts=opts.LineStyleOpts(color="#d6dcde"),); radar_team1.add('SEA', v32, linestyle_opts=opts.LineStyleOpts(color="#01391d"),); 
radar_team1.add('TOR', v33, linestyle_opts=opts.LineStyleOpts(color="#bd0f33"),); radar_team1.add('UTA', v34, linestyle_opts=opts.LineStyleOpts(color="#2c4e37"),); 
radar_team1.add('VAN', v35, linestyle_opts=opts.LineStyleOpts(color="#0cb3a9"),); radar_team1.add('WAS', v36, linestyle_opts=opts.LineStyleOpts(color="#002043"),); 
radar_team1.add('WSB', v37, linestyle_opts=opts.LineStyleOpts(color="#0142ac"),); 

radar_team1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar_team1.set_global_opts(legend_opts=opts.LegendOpts(type_="scroll", selected_mode="single", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),                            
                           title_opts=opts.TitleOpts(title="Regular-Team", pos_top='bottom', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                           )

radar_team1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="32ef5f0f812642178d1cdd81b2090261" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_32ef5f0f812642178d1cdd81b2090261 = echarts.init(
#             document.getElementById('32ef5f0f812642178d1cdd81b2090261'), 'white', {renderer: 'canvas'});
#         var option_32ef5f0f812642178d1cdd81b2090261 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### radar2

# %%
a18 = [age_m.loc[18][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a19 = [age_m.loc[19][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a20 = [age_m.loc[20][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a21 = [age_m.loc[21][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a22 = [age_m.loc[22][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a23 = [age_m.loc[23][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a24 = [age_m.loc[24][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a25 = [age_m.loc[25][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a26 = [age_m.loc[26][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a27 = [age_m.loc[27][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a28 = [age_m.loc[28][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a29 = [age_m.loc[29][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a30 = [age_m.loc[30][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a31 = [age_m.loc[31][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a32 = [age_m.loc[32][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a33 = [age_m.loc[33][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a34 = [age_m.loc[34][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a35 = [age_m.loc[35][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 
a36 = [age_m.loc[36][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; a37 = [age_m.loc[37][['G', 'MPP', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].to_list()]; 

radar_team2 = Radar(figsize)
radar_team2.add_schema(
        schema=[
            opts.RadarIndicatorItem(name="Games", max_=82, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Minutes", max_=42, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Total Rebounds", max_=7, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Assists", max_=6.5, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Steals", max_=2.5, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Blocks", max_=1, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Turnovers", max_=6, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Personal Fouls", max_=3.5, color='#FFFF99'),
            opts.RadarIndicatorItem(name="Points", max_=36, color='#FFFF99'),
        ],
        shape='circle'
)

radar_team2.add('18', a18, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('19', a19, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('20', a20, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('21', a21, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('22', a22, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('23', a23, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('24', a24, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('25', a25, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('26', a26, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('27', a27, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('28', a28, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('29', a29, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('30', a30, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('31', a31, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('32', a32, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('33', a33, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('34', a34, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('35', a35, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 
radar_team2.add('36', a36, linestyle_opts=opts.LineStyleOpts(color="#fbc735"),); radar_team2.add('37', a37, linestyle_opts=opts.LineStyleOpts(color="#663d7f"),); 

radar_team2.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar_team2.set_global_opts(legend_opts=opts.LegendOpts(type_="scroll", selected_mode="single", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                           title_opts=opts.TitleOpts(title="Regular-Age", pos_top='bottom', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                           )
radar_team2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="0c2799dd957344c98709a68419339bac" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_0c2799dd957344c98709a68419339bac = echarts.init(
#             document.getElementById('0c2799dd957344c98709a68419339bac'), 'white', {renderer: 'canvas'});
#         var option_0c2799dd957344c98709a68419339bac = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ## Sunburst

# %%
sunburst_data = [
    {
        "name": "Home",
        "itemStyle": {"color": "#fbc735"},
        'children': [
            {"name": "#WIN", "value": int(home_away['W/L.1'][0]), "itemStyle": {"color": "#feb846"}},
            {"name": "#LOSE", "value": int(home_away['W/L.1'][1]), "itemStyle": {"color": "#4c4632"}},
        ]
    },
    
    {
        "name": "Away",
        "itemStyle": {"color": "#663d7f"},
        'children': [
            {"name": "@WIN", "value": int(home_away['W/L.1'][2]), "itemStyle": {"color": "#feb846"}},
            {"name": "@LOSE", "value": int(home_away['W/L.1'][3]), "itemStyle": {"color": "#4c4632"}},
        ]
    }
    
]

Sunburst1 = Sunburst(figsize)
    
Sunburst1.add(
        series_name="", 
        data_pair=sunburst_data,
        
    )

Sunburst1.set_global_opts(title_opts=opts.TitleOpts(title="Win-Lose", title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')))
Sunburst1.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
Sunburst1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a644830d03254534ac5d057e6b16bed6" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_a644830d03254534ac5d057e6b16bed6 = echarts.init(
#             document.getElementById('a644830d03254534ac5d057e6b16bed6'), 'white', {renderer: 'canvas'});
#         var option_a644830d03254534ac5d057e6b16bed6 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ## Heatmap

# %% [markdown]
# ### heatmap1

# %%
team_list = win_lose_team.index.dropna().to_list()
win_list = win_lose_team[win_lose_team['W/L']=='W'].iloc[:,1].to_list()
lose_list = win_lose_team[win_lose_team['W/L']=='L'].iloc[:,1].to_list()
lose_list.insert(2, 0)
lose_list.insert(36, 0)
t_list = [win_list, lose_list]
t_list;

# %%
heatmap1 = HeatMap(figsize)

value = [[i, j, int(t_list[j][i])] for i in range(37) for j in range(2)]
heatmap1.add_xaxis(team_list)
heatmap1.add_yaxis('', ['WIN', 'LOSE'], value)
heatmap1.set_global_opts(title_opts=opts.TitleOpts(title="Win-Lose-Team", pos_right='40%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                        xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                        yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                        visualmap_opts=opts.VisualMapOpts(max_=51, pos_right='right', textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
                       )

heatmap1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7af1406283194baa9a928d08a407627a" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_7af1406283194baa9a928d08a407627a = echarts.init(
#             document.getElementById('7af1406283194baa9a928d08a407627a'), 'white', {renderer: 'canvas'});
#         var option_7af1406283194baa9a928d08a407627a = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### heatmap2

# %%
age_list = win_lose_age.index.dropna().to_list()
list_win = win_lose_age[win_lose_age['W/L']=='W'].iloc[:,1].to_list()
list_lose = win_lose_age[win_lose_age['W/L']=='L'].iloc[:,1].to_list()
a_list = [list_win, list_lose]
a_list;

# %%
heatmap2 = HeatMap(figsize)

value = [[i, j, int(a_list[j][i])] for i in range(20) for j in range(2)]
heatmap2.add_xaxis(age_list)
heatmap2.add_yaxis('', ['WIN', 'LOSE'], value)
heatmap2.set_global_opts(title_opts=opts.TitleOpts(title="Win-Lose-Age", pos_right='40%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                        xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                        yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                        visualmap_opts=opts.VisualMapOpts(max_=65, pos_right='right', textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
                       )

heatmap2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5a162c39f20147079e74ebb32ab797ff" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_5a162c39f20147079e74ebb32ab797ff = echarts.init(
#             document.getElementById('5a162c39f20147079e74ebb32ab797ff'), 'white', {renderer: 'canvas'});
#         var option_5a162c39f20147079e74ebb32ab797ff = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ## Pie

# %%
adata = s_age.reset_index()

# %% [markdown]
# ### Games

# %%
aG = np.array(adata[['AgeY','G']]).tolist()

pie1 = Pie(figsize) 

pie1.add('', aG, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie1.set_global_opts(title_opts=opts.TitleOpts(title='Games', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie1.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="839226163c284e9d8dc2a6cf89374d18" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_839226163c284e9d8dc2a6cf89374d18 = echarts.init(
#             document.getElementById('839226163c284e9d8dc2a6cf89374d18'), 'white', {renderer: 'canvas'});
#         var option_839226163c284e9d8dc2a6cf89374d18 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### PTS

# %%
aPTS = np.array(adata[['AgeY','PTS']]).tolist()

pie2 = Pie(figsize) 

pie2.add('', aPTS, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie2.set_global_opts(title_opts=opts.TitleOpts(title='Points', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie2.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="bb08d2698cca47c3addddc3bd354ce67" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_bb08d2698cca47c3addddc3bd354ce67 = echarts.init(
#             document.getElementById('bb08d2698cca47c3addddc3bd354ce67'), 'white', {renderer: 'canvas'});
#         var option_bb08d2698cca47c3addddc3bd354ce67 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### AST

# %%
aAST = np.array(adata[['AgeY','AST']]).tolist()

pie3 = Pie(figsize) 

pie3.add('', aAST, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie3.set_global_opts(title_opts=opts.TitleOpts(title='Assists', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie3.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie3.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="09f9490c63e74dd1982efb9b7b691ae8" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_09f9490c63e74dd1982efb9b7b691ae8 = echarts.init(
#             document.getElementById('09f9490c63e74dd1982efb9b7b691ae8'), 'white', {renderer: 'canvas'});
#         var option_09f9490c63e74dd1982efb9b7b691ae8 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### TRB

# %%
aTRB = np.array(adata[['AgeY','TRB']]).tolist()

pie4 = Pie(figsize) 

pie4.add('', aTRB, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie4.set_global_opts(title_opts=opts.TitleOpts(title='Total Rebounds', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie4.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie4.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="50a088d1ab8947e6a3b06d19a6e24b25" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_50a088d1ab8947e6a3b06d19a6e24b25 = echarts.init(
#             document.getElementById('50a088d1ab8947e6a3b06d19a6e24b25'), 'white', {renderer: 'canvas'});
#         var option_50a088d1ab8947e6a3b06d19a6e24b25 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### STL

# %%
aSTL = np.array(adata[['AgeY','STL']]).tolist()

pie5 = Pie(figsize) 

pie5.add('', aSTL, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie5.set_global_opts(title_opts=opts.TitleOpts(title='Steals', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie5.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie5.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="61ac7b3e8e4641a0a1a3d026e2442a1f" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_61ac7b3e8e4641a0a1a3d026e2442a1f = echarts.init(
#             document.getElementById('61ac7b3e8e4641a0a1a3d026e2442a1f'), 'white', {renderer: 'canvas'});
#         var option_61ac7b3e8e4641a0a1a3d026e2442a1f = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### BLK

# %%
aBLK = np.array(adata[['AgeY','BLK']]).tolist()

pie6 = Pie(figsize) 

pie6.add('', aBLK, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie6.set_global_opts(title_opts=opts.TitleOpts(title='Blocks', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie6.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie6.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="59eb6466bd974a3e8475b71b75cb55bc" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_59eb6466bd974a3e8475b71b75cb55bc = echarts.init(
#             document.getElementById('59eb6466bd974a3e8475b71b75cb55bc'), 'white', {renderer: 'canvas'});
#         var option_59eb6466bd974a3e8475b71b75cb55bc = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### TOV

# %%
aTOV = np.array(adata[['AgeY','TOV']]).tolist()

pie7 = Pie(figsize) 

pie7.add('', aTOV, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie7.set_global_opts(title_opts=opts.TitleOpts(title='Turnovers', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie7.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie7.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="520625c3b90d4e598cf149e65523d653" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_520625c3b90d4e598cf149e65523d653 = echarts.init(
#             document.getElementById('520625c3b90d4e598cf149e65523d653'), 'white', {renderer: 'canvas'});
#         var option_520625c3b90d4e598cf149e65523d653 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### PF

# %%
aPF = np.array(adata[['AgeY','PF']]).tolist()

pie8 = Pie(figsize) 

pie8.add('', aPF, rosetype='area', radius=["24%", "75%"], label_opts=opts.LabelOpts(is_show=False))
pie8.set_global_opts(title_opts=opts.TitleOpts(title='Personal Fouls', pos_top='bottom', pos_left='1%', title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')), 
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'))
                    )
pie8.set_series_opts(label_opts=opts.LabelOpts(position="outside", 
                                               formatter="{per|{b} year-old: {c}}",
                                               background_color="#eee",
                                               border_color="#aaa",
                                               border_width=1,
                                               border_radius=4,
                                               rich={
                                                     "per": {
                                                             "color": "#eee",
                                                             "backgroundColor": "#334455",
                                                             "padding": [2, 4],
                                                             "borderRadius": 2,
                                                            },
                                                    },
                                              ))
pie8.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="8f33d591dda34ed8bc4268971b9a7aa6" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_8f33d591dda34ed8bc4268971b9a7aa6 = echarts.init(
#             document.getElementById('8f33d591dda34ed8bc4268971b9a7aa6'), 'white', {renderer: 'canvas'});
#         var option_8f33d591dda34ed8bc4268971b9a7aa6 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
# ...

# %% [markdown]
# ### Timeline

# %%
timeline = Timeline(figsize)
timeline.add(pie1, "Games")
timeline.add(pie2, "Points")
timeline.add(pie3, "Assists")
timeline.add(pie4, "Total Rebounds")
timeline.add(pie5, "Steals")
timeline.add(pie6, "Blocks")
timeline.add(pie7, "Turnovers")
timeline.add(pie8, "Personal Fouls")

timeline.add_schema(
                    symbol='diamond', 
                    symbol_size=8, 
                    play_interval=1500, 
                    is_auto_play=True,
                    label_opts=opts.LabelOpts(is_show=False),
                    itemstyle_opts=opts.ItemStyleOpts(color='#FFFF99')
        )

timeline.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7c5381d480b642db92f0212f593075ba" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_7c5381d480b642db92f0212f593075ba = echarts.init(
#             document.getElementById('7c5381d480b642db92f0212f593075ba'), 'white', {renderer: 'canvas'});
#         var option_7c5381d480b642db92f0212f593075ba = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": 18,
#                         "value": 102
#                     },
#                     {
#                         "name": 19,
#                         "value": 180
#                     },
#                     {
#                         "name": 20,
#                         "value": 153
#                     },
# ...

# %% [markdown]
# ## Bar

# %% [markdown]
# ### bar1

# %%
bar1 = Bar(figsize) 
bar1.add_xaxis(s_team.index.tolist())

bar1.add_yaxis('Games', s_team.G.tolist(), yaxis_index=1, color='#0cb3a9') 
bar1.add_yaxis('Points', s_team.PTS.tolist(), yaxis_index=0, color='#0071bb') 
bar1.add_yaxis('Assists', s_team.AST.tolist(), yaxis_index=0, color='#f1a8bb') 
bar1.add_yaxis('Total Rebounds', s_team.TRB.tolist(), yaxis_index=0, color='#663d7f') 
bar1.add_yaxis('Steals', s_team.STL.tolist(), yaxis_index=0, color='#cc082f') 
bar1.add_yaxis('Blocks', s_team.BLK.tolist(), yaxis_index=0, color='#4c4632') 
bar1.add_yaxis('Turnovers', s_team.TOV.tolist(), yaxis_index=0, color='#feb846') 
bar1.add_yaxis('Personal Fouls', s_team.PF.tolist(), yaxis_index=0, color='#007a30') 

bar1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

bar1.extend_axis(yaxis=opts.AxisOpts( axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))))
bar1.set_global_opts(title_opts=opts.TitleOpts(title='Team-Sum', pos_bottom = 'bottom', pos_right='40%', padding=[1,5], title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
                     legend_opts=opts.LegendOpts(type_="scroll", textstyle_opts=opts.TextStyleOpts(color='#FFFF99'), selected_mode="single"),
                     tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     
                    ) 

bar1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="29701a8aa6ec4f8e80f2960ddb8b7236" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_29701a8aa6ec4f8e80f2960ddb8b7236 = echarts.init(
#             document.getElementById('29701a8aa6ec4f8e80f2960ddb8b7236'), 'white', {renderer: 'canvas'});
#         var option_29701a8aa6ec4f8e80f2960ddb8b7236 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#007a30",
#         "#feb846",
#         "#4c4632",
#         "#cc082f",
#         "#663d7f",
#         "#f1a8bb",
#         "#0071bb",
#         "#0cb3a9",
#         "#c23531",
#         "#2f4554",
# ...

# %% [markdown]
# ### bar2

# %%
bar2 = Bar(figsize) 
bar2.add_xaxis(sp_team.index.to_list())

bar2.add_yaxis('Max Win Score', sp_team.MAX.to_list(), yaxis_index=0, color='#663d7f', stack="stack1") 
bar2.add_yaxis('Max Lose Score', sp_team.MIN.to_list(), yaxis_index=0, color='#feb846', stack="stack1") 
bar2.add_yaxis('Max Plus', sp_team.P_MAX.to_list(), yaxis_index=1, color='#fbc735', stack="stack2") 
bar2.add_yaxis('Max Minus', sp_team.N_MIN.to_list(), yaxis_index=1, color='#cc082f', stack="stack2") 

bar2.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

bar2.extend_axis(yaxis=opts.AxisOpts( axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))))
bar2.set_global_opts(title_opts=opts.TitleOpts(title='Plus-Minus-Team', pos_top='top', padding=[1,5], title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
                     legend_opts=opts.LegendOpts(textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     
                    ) 

bar2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="66fd3aeff6c3408cb4c51f0688d7c961" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_66fd3aeff6c3408cb4c51f0688d7c961 = echarts.init(
#             document.getElementById('66fd3aeff6c3408cb4c51f0688d7c961'), 'white', {renderer: 'canvas'});
#         var option_66fd3aeff6c3408cb4c51f0688d7c961 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#cc082f",
#         "#fbc735",
#         "#feb846",
#         "#663d7f",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### bar3

# %%
bar3 = Bar(figsize) 
bar3.add_xaxis(sp_age.index.to_list())

bar3.add_yaxis('Max Win Score', sp_age.MAX.to_list(), yaxis_index=0, color='#663d7f', stack="stack1") 
bar3.add_yaxis('Max Lose Score', sp_age.MIN.to_list(), yaxis_index=0, color='#feb846', stack="stack1") 
bar3.add_yaxis('Max Plus', sp_age.P_MAX.to_list(), yaxis_index=1, color='#fbc735', stack="stack2") 
bar3.add_yaxis('Max Minus', sp_age.N_MIN.to_list(), yaxis_index=1, color='#cc082f', stack="stack2") 

bar3.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

bar3.extend_axis(yaxis=opts.AxisOpts( axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))))
bar3.set_global_opts(title_opts=opts.TitleOpts(title='Plus-Minus-Age', pos_top='top', padding=[1,5], title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                     datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
                     legend_opts=opts.LegendOpts(textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                     
                    ) 

bar3.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6c5f2cfd06be438c9aadb3b674d4047a" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_6c5f2cfd06be438c9aadb3b674d4047a = echarts.init(
#             document.getElementById('6c5f2cfd06be438c9aadb3b674d4047a'), 'white', {renderer: 'canvas'});
#         var option_6c5f2cfd06be438c9aadb3b674d4047a = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#cc082f",
#         "#fbc735",
#         "#feb846",
#         "#663d7f",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## Line

# %% [markdown]
# ### line1

# %%
line1 = Line(figsize) 
line1.add_xaxis(team_m.index.to_list())

line1.add_yaxis('FGP', team_m.FGP.to_list(), yaxis_index=0, color='#007a30')
line1.add_yaxis('3PP', team_m['3PP'].to_list(), yaxis_index=0, color='#663d7f')
line1.add_yaxis('FTP', team_m.FTP.to_list(), yaxis_index=0, color='#feb846')

line1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

line1.extend_axis(yaxis=opts.AxisOpts( axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))))
line1.set_global_opts(title_opts=opts.TitleOpts(title='Shooting-Team', pos_left = 'right', padding=[1,5], title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                      xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                      yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                      legend_opts=opts.LegendOpts(textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                      tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                      datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],

                    ) 


line1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a84a5e65c7264adaa5a1a6449f478008" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_a84a5e65c7264adaa5a1a6449f478008 = echarts.init(
#             document.getElementById('a84a5e65c7264adaa5a1a6449f478008'), 'white', {renderer: 'canvas'});
#         var option_a84a5e65c7264adaa5a1a6449f478008 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#feb846",
#         "#663d7f",
#         "#007a30",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
# ...

# %% [markdown]
# ### line2

# %%
line2 = Line(figsize) 
line2.add_xaxis(age_m.index.astype(str).to_list())

line2.add_yaxis('FGP', age_m.FGP.to_list(), yaxis_index=0, color='#007a30')
line2.add_yaxis('3PP', age_m['3PP'].to_list(), yaxis_index=0, color='#663d7f')
line2.add_yaxis('FTP', age_m.FTP.to_list(), yaxis_index=0, color='#feb846')

line2.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

# line2.extend_axis(yaxis=opts.AxisOpts( axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))))
line2.set_global_opts(title_opts=opts.TitleOpts(title='Shooting-Age', pos_left = 'top', padding=[1,5], title_textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                      xaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                      yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color='#FFFF99'))),
                      legend_opts=opts.LegendOpts(textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
                      tooltip_opts=opts.TooltipOpts(is_show=True, trigger="axis", textstyle_opts=opts.TextStyleOpts(color='#FFFF99')),
#                       datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],

                    ) 


line2.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="cc65ba290c304e52a1d69b98793417a7" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_cc65ba290c304e52a1d69b98793417a7 = echarts.init(
#             document.getElementById('cc65ba290c304e52a1d69b98793417a7'), 'white', {renderer: 'canvas'});
#         var option_cc65ba290c304e52a1d69b98793417a7 = {
#     "backgroundColor": "rgb(5, 46, 112, 0.5)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#feb846",
#         "#663d7f",
#         "#007a30",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
# ...

# %% [markdown]
# ## title

# %%
title = Pie().set_global_opts(title_opts=opts.TitleOpts(title="科比常规赛数据大屏", title_textstyle_opts=opts.TextStyleOpts(font_size=40, color='#fbc735'), pos_top=0)) # 黄：fbc735 紫：663d7f
title.render_notebook();

# %% [markdown]
# ## page

# %%
page = Page(layout=Page.DraggablePageLayout, page_title='科比常规赛数据大屏')
page.add(
         radar_team1,
         radar_team2, 
         Sunburst1,
         heatmap1,
         heatmap2, 
         timeline,
         bar1,
         bar2,
         bar3,
         line1, 
         line2,
         title
        )
page.render('BI_Kobe_Regular.html')
# Out:
# 'D:\\ASUS\\JupyterSource\\Python数据分析与可视化\\NBA数据分析及可视化\\BI_Kobe_Regular.html'

# %%
from bs4 import BeautifulSoup
with open("BI_Kobe_Regular.html", "r+", encoding='utf-8') as html:
    html_bf = BeautifulSoup(html, 'lxml')
    body = html_bf.find("body")
    body["background"] = "https://wx4.sinaimg.cn/large/7f68d8d2gy1gwzm9xbnb6j21z4140ttk.jpg"  # 背景颜色
    html_new = str(html_bf)
    html.seek(0, 0)
    html.truncate()
    html.write(html_new)
    html.close()

# %%
# <body style="background-image: url(KB3.jpg)">

# %%
Page.save_resize_html("BI_Kobe_Regular.html", cfg_file=r"KB_Re.json", dest="Kobe_Regular_BI.html");
